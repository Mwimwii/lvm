# %%
# Installation

# Clone the default reference voice repo (if not already present)
# !git clone https://github.com/Mwimwii/vo.git 2>/dev/null || echo 'vo/ already exists'

# Install dependencies
# !pip install -r requirements.txt --quiet

print('Ready. Run the next cell to launch the UI.')

# %%
# Launch the Gradio UI
# --share creates a public URL. Remove it if running locally.
# !python app.py --share
